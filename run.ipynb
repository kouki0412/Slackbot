# %%
# %run run.py
# Out:
# starting slackbot
# 1332
# []
# ['1']
# 候補文 [晴れるといいですね。, 1.19204]
# 候補文 [天気がいいと気持ちもいいですね。, 1.10355]
# 候補文 [天気予報って当たらないですよね。, 1.59458]
# 候補文 [天気が悪い日は家にこもりたいですね。, 1.71313]
# 候補文 [いつか天気を操ることが出来たらいいですね。, 1.62832]
# 候補文 [天気って何ですか？, 0.89952]
# 候補文 [それで？, 0.97786]
# 候補文 [よかったね, 0.92288]
# []
# ['1']
# 候補文 [晴れるといいですね。, 1.13593]
# 候補文 [天気がいいと気持ちもいいですね。, 1.27724]
# 候補文 [天気予報って当たらないですよね。, 1.39082]
# 候補文 [天気が悪い日は家にこもりたいですね。, 1.17409]
# 候補文 [いつか天気を操ることが出来たらいいですね。, 1.96822]
# 候補文 [天気って何ですか？, 0.70383]
# 候補文 [それで？, 0.73345]
# 候補文 [よかったね, 1.09796]
# []
# ['1']
# 候補文 [晴れるといいですね。, 1.82555]
# 候補文 [天気がいいと気持ちもいいですね。, 1.59741]
# 候補文 [天気予報って当たらないですよね。, 1.72637]
# 候補文 [天気が悪い日は家にこもりたいですね。, 1.76613]
# 候補文 [いつか天気を操ることが出来たらいいですね。, 1.62927]
# 候補文 [天気は好きですか？, 1.42435]
# 候補文 [なるほど, 1.23444]
# 候補文 [よかったね, 1.29047]
# []
# ['1']
# 候補文 [晴れるといいですね。, 1.19064]
# 候補文 [天気がいいと気持ちもいいですね。, 1.67504]
# 候補文 [天気予報って当たらないですよね。, 1.57344]
# 候補文 [天気が悪い日は家にこもりたいですね。, 1.40922]
# 候補文 [いつか天気を操ることが出来たらいいですね。, 1.52430]
# ...
